# %%
using Revise
using RigidBodyDynamics
using StaticArrays
using MeshCat
using AtlasRobot
using MeshCatMechanisms

# %%
mechanism = AtlasRobot.mechanism()
mvis = MechanismVisualizer(mechanism)
IJuliaCell(mvis)
# Out:
# Listening on 127.0.0.1:7003...
# zmq_url=tcp://127.0.0.1:6003
# web_url=http://127.0.0.1:7003/static/
# ...

# %%
vis = Visualizer()
mv1 = MechanismVisualizer(mechanism, create_skeleton(mechanism, show_inertias=true), vis[:skeleton])
mv2 = MechanismVisualizer(mechanism, AtlasRobot.urdfpath(), vis[:urdf], package_path=[AtlasRobot.packagepath()])
IJuliaCell(vis)
# Out:
# Listening on 127.0.0.1:7004...
# zmq_url=tcp://127.0.0.1:6004
# web_url=http://127.0.0.1:7004/static/
# ...
